# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms.v2 as transforms
import matplotlib.pyplot as plt

# 데이터 변환 및 로드
transform = transforms.Compose([
    transforms.ToTensor()
])

# 학습 데이터셋 (일부만 사용하여 오버피팅 유도)
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
subset_indices = torch.arange(0, 2000)  # 학습 데이터 2000개만 사용
train_subset = torch.utils.data.Subset(train_dataset, subset_indices)
train_loader = torch.utils.data.DataLoader(train_subset, batch_size=64, shuffle=True)

# 테스트 데이터셋
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# c:\sk-encoa\dl_workspace\.venv\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
class OverfittingNet(nn.Module):
    def __init__(self):
        super(OverfittingNet, self).__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(1*28*28, 512)
        self.relu1 = nn.ReLU()
        self.layer2 = nn.Linear(512, 256)
        self.relu2 = nn.ReLU()
        self.layer3 = nn.Linear(256, 128)
        self.relu3 = nn.ReLU()
        self.layer4 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu1(self.layer1(x))
        x = self.relu2(self.layer2(x))
        x = self.relu3(self.layer3(x))
        x = self.layer4(x)
        return x

# 모델, 손실 함수, 옵티마이저 정의
model = OverfittingNet()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# 학습 함수
def train(model, loader, optimizer, criterion):
    model.train()
    running_loss = 0.0
    for inputs, targets in loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(loader)

# 평가 함수
def evaluate(model, loader, criterion):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    accuracy = 100 * correct / total
    return running_loss / len(loader), accuracy

# %%
# 학습 및 평가 기록을 저장할 리스트
train_losses = []
test_losses = []
test_accuracies = []

num_epochs = 100
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, optimizer, criterion)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion)

    train_losses.append(train_loss)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

    print(f'Epoch [{epoch+1}/{num_epochs}] - Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.2f}%')

# 손실 곡선 시각화
plt.figure(figsize=(10,5))
plt.title('Loss')
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 정확도 곡선 시각화
plt.figure(figsize=(10,5))
plt.title('Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()
# Out:
# Epoch [1/100] - Train Loss: 1.0920, Test Loss: 0.5726, Accuracy: 81.58%
# Epoch [2/100] - Train Loss: 0.3886, Test Loss: 0.5481, Accuracy: 84.76%
# Epoch [3/100] - Train Loss: 0.3016, Test Loss: 0.4811, Accuracy: 86.54%
# Epoch [4/100] - Train Loss: 0.2301, Test Loss: 0.4172, Accuracy: 88.78%
# Epoch [5/100] - Train Loss: 0.1610, Test Loss: 0.4355, Accuracy: 89.27%
# Epoch [6/100] - Train Loss: 0.1118, Test Loss: 0.4217, Accuracy: 90.63%
# Epoch [7/100] - Train Loss: 0.0854, Test Loss: 0.5570, Accuracy: 89.71%
# Epoch [8/100] - Train Loss: 0.0999, Test Loss: 0.5846, Accuracy: 88.78%
# Epoch [9/100] - Train Loss: 0.1113, Test Loss: 0.5869, Accuracy: 87.85%
# Epoch [10/100] - Train Loss: 0.0715, Test Loss: 0.5729, Accuracy: 89.40%
# Epoch [11/100] - Train Loss: 0.1338, Test Loss: 0.6439, Accuracy: 87.48%
# Epoch [12/100] - Train Loss: 0.1794, Test Loss: 0.7132, Accuracy: 87.35%
# Epoch [13/100] - Train Loss: 0.1382, Test Loss: 0.9044, Accuracy: 86.71%
# Epoch [14/100] - Train Loss: 0.1725, Test Loss: 0.4782, Accuracy: 90.29%
# Epoch [15/100] - Train Loss: 0.1087, Test Loss: 0.8499, Accuracy: 87.20%
# Epoch [16/100] - Train Loss: 0.1069, Test Loss: 0.5845, Accuracy: 90.87%
# Epoch [17/100] - Train Loss: 0.0758, Test Loss: 0.7615, Accuracy: 89.67%
# Epoch [18/100] - Train Loss: 0.0910, Test Loss: 0.5515, Accuracy: 91.45%
# Epoch [19/100] - Train Loss: 0.0270, Test Loss: 0.6572, Accuracy: 91.85%
# Epoch [20/100] - Train Loss: 0.0094, Test Loss: 0.7422, Accuracy: 91.47%
# Epoch [21/100] - Train Loss: 0.0164, Test Loss: 1.0045, Accuracy: 89.93%
# Epoch [22/100] - Train Loss: 0.0455, Test Loss: 0.5738, Accuracy: 92.21%
# Epoch [23/100] - Train Loss: 0.0263, Test Loss: 0.7878, Accuracy: 90.94%
# Epoch [24/100] - Train Loss: 0.0113, Test Loss: 1.0034, Accuracy: 90.93%
# Epoch [25/100] - Train Loss: 0.0511, Test Loss: 0.6684, Accuracy: 91.18%
# Epoch [26/100] - Train Loss: 0.0671, Test Loss: 0.6579, Accuracy: 90.55%
# Epoch [27/100] - Train Loss: 0.1161, Test Loss: 0.9571, Accuracy: 88.94%
# Epoch [28/100] - Train Loss: 0.2299, Test Loss: 0.6498, Accuracy: 89.23%
# Epoch [29/100] - Train Loss: 0.0495, Test Loss: 0.8822, Accuracy: 90.52%
# Epoch [30/100] - Train Loss: 0.0288, Test Loss: 0.9331, Accuracy: 90.44%
# Epoch [31/100] - Train Loss: 0.0387, Test Loss: 0.8663, Accuracy: 90.70%
# Epoch [32/100] - Train Loss: 0.0120, Test Loss: 0.8867, Accuracy: 90.94%
# Epoch [33/100] - Train Loss: 0.0267, Test Loss: 0.7948, Accuracy: 91.60%
# Epoch [34/100] - Train Loss: 0.0338, Test Loss: 1.1631, Accuracy: 91.01%
# Epoch [35/100] - Train Loss: 0.2513, Test Loss: 0.7363, Accuracy: 87.52%
# Epoch [36/100] - Train Loss: 0.0765, Test Loss: 0.6513, Accuracy: 90.93%
# Epoch [37/100] - Train Loss: 0.0443, Test Loss: 1.0452, Accuracy: 89.09%
# Epoch [38/100] - Train Loss: 0.1180, Test Loss: 0.8289, Accuracy: 91.05%
# Epoch [39/100] - Train Loss: 0.1471, Test Loss: 1.3077, Accuracy: 87.67%
# Epoch [40/100] - Train Loss: 0.1520, Test Loss: 0.9126, Accuracy: 89.65%
# Epoch [41/100] - Train Loss: 0.1568, Test Loss: 0.8665, Accuracy: 90.36%
# Epoch [42/100] - Train Loss: 0.0845, Test Loss: 0.9708, Accuracy: 90.76%
# Epoch [43/100] - Train Loss: 0.0827, Test Loss: 1.0200, Accuracy: 91.28%
# Epoch [44/100] - Train Loss: 0.1059, Test Loss: 0.7687, Accuracy: 90.30%
# Epoch [45/100] - Train Loss: 0.0442, Test Loss: 1.0075, Accuracy: 90.90%
# Epoch [46/100] - Train Loss: 0.0198, Test Loss: 0.8889, Accuracy: 91.66%
# Epoch [47/100] - Train Loss: 0.0546, Test Loss: 0.7978, Accuracy: 91.84%
# Epoch [48/100] - Train Loss: 0.0011, Test Loss: 0.8041, Accuracy: 91.94%
# Epoch [49/100] - Train Loss: 0.0006, Test Loss: 0.8088, Accuracy: 91.93%
# Epoch [50/100] - Train Loss: 0.0002, Test Loss: 0.8160, Accuracy: 91.89%
# Epoch [51/100] - Train Loss: 0.0001, Test Loss: 0.8199, Accuracy: 91.95%
# Epoch [52/100] - Train Loss: 0.0001, Test Loss: 0.8228, Accuracy: 91.94%
# Epoch [53/100] - Train Loss: 0.0001, Test Loss: 0.8251, Accuracy: 91.94%
# Epoch [54/100] - Train Loss: 0.0001, Test Loss: 0.8278, Accuracy: 91.94%
# Epoch [55/100] - Train Loss: 0.0000, Test Loss: 0.8299, Accuracy: 91.95%
# Epoch [56/100] - Train Loss: 0.0000, Test Loss: 0.8319, Accuracy: 91.96%
# Epoch [57/100] - Train Loss: 0.0000, Test Loss: 0.8335, Accuracy: 91.97%
# Epoch [58/100] - Train Loss: 0.0000, Test Loss: 0.8353, Accuracy: 91.97%
# Epoch [59/100] - Train Loss: 0.0000, Test Loss: 0.8370, Accuracy: 92.00%
# Epoch [60/100] - Train Loss: 0.0000, Test Loss: 0.8387, Accuracy: 91.99%
# Epoch [61/100] - Train Loss: 0.0000, Test Loss: 0.8401, Accuracy: 92.00%
# Epoch [62/100] - Train Loss: 0.0000, Test Loss: 0.8416, Accuracy: 92.00%
# Epoch [63/100] - Train Loss: 0.0000, Test Loss: 0.8434, Accuracy: 92.01%
# Epoch [64/100] - Train Loss: 0.0000, Test Loss: 0.8448, Accuracy: 92.02%
# Epoch [65/100] - Train Loss: 0.0000, Test Loss: 0.8461, Accuracy: 92.01%
# Epoch [66/100] - Train Loss: 0.0000, Test Loss: 0.8475, Accuracy: 92.01%
# Epoch [67/100] - Train Loss: 0.0000, Test Loss: 0.8487, Accuracy: 92.00%
# Epoch [68/100] - Train Loss: 0.0000, Test Loss: 0.8500, Accuracy: 92.00%
# Epoch [69/100] - Train Loss: 0.0000, Test Loss: 0.8513, Accuracy: 92.00%
# Epoch [70/100] - Train Loss: 0.0000, Test Loss: 0.8525, Accuracy: 91.98%
# Epoch [71/100] - Train Loss: 0.0000, Test Loss: 0.8536, Accuracy: 92.00%
# Epoch [72/100] - Train Loss: 0.0000, Test Loss: 0.8547, Accuracy: 91.99%
# Epoch [73/100] - Train Loss: 0.0000, Test Loss: 0.8561, Accuracy: 92.00%
# Epoch [74/100] - Train Loss: 0.0000, Test Loss: 0.8569, Accuracy: 92.02%
# Epoch [75/100] - Train Loss: 0.0000, Test Loss: 0.8582, Accuracy: 92.03%
# Epoch [76/100] - Train Loss: 0.0000, Test Loss: 0.8591, Accuracy: 92.02%
# Epoch [77/100] - Train Loss: 0.0000, Test Loss: 0.8602, Accuracy: 92.02%
# Epoch [78/100] - Train Loss: 0.0000, Test Loss: 0.8613, Accuracy: 92.02%
# Epoch [79/100] - Train Loss: 0.0000, Test Loss: 0.8623, Accuracy: 92.02%
# Epoch [80/100] - Train Loss: 0.0000, Test Loss: 0.8635, Accuracy: 92.02%
# Epoch [81/100] - Train Loss: 0.0000, Test Loss: 0.8645, Accuracy: 92.03%
# Epoch [82/100] - Train Loss: 0.0000, Test Loss: 0.8655, Accuracy: 92.03%
# Epoch [83/100] - Train Loss: 0.0000, Test Loss: 0.8668, Accuracy: 92.03%
# Epoch [84/100] - Train Loss: 0.0000, Test Loss: 0.8678, Accuracy: 92.03%
# Epoch [85/100] - Train Loss: 0.0000, Test Loss: 0.8689, Accuracy: 92.03%
# Epoch [86/100] - Train Loss: 0.0000, Test Loss: 0.8698, Accuracy: 92.05%
# Epoch [87/100] - Train Loss: 0.0000, Test Loss: 0.8703, Accuracy: 92.06%
# Epoch [88/100] - Train Loss: 0.0000, Test Loss: 0.8713, Accuracy: 92.07%
# Epoch [89/100] - Train Loss: 0.0000, Test Loss: 0.8723, Accuracy: 92.08%
# Epoch [90/100] - Train Loss: 0.0000, Test Loss: 0.8733, Accuracy: 92.08%
# Epoch [91/100] - Train Loss: 0.0000, Test Loss: 0.8742, Accuracy: 92.08%
# Epoch [92/100] - Train Loss: 0.0000, Test Loss: 0.8752, Accuracy: 92.08%
# Epoch [93/100] - Train Loss: 0.0000, Test Loss: 0.8760, Accuracy: 92.09%
# Epoch [94/100] - Train Loss: 0.0000, Test Loss: 0.8770, Accuracy: 92.09%
# Epoch [95/100] - Train Loss: 0.0000, Test Loss: 0.8779, Accuracy: 92.09%
# Epoch [96/100] - Train Loss: 0.0000, Test Loss: 0.8788, Accuracy: 92.09%
# Epoch [97/100] - Train Loss: 0.0000, Test Loss: 0.8798, Accuracy: 92.09%
# Epoch [98/100] - Train Loss: 0.0000, Test Loss: 0.8807, Accuracy: 92.09%
# Epoch [99/100] - Train Loss: 0.0000, Test Loss: 0.8817, Accuracy: 92.10%
# Epoch [100/100] - Train Loss: 0.0000, Test Loss: 0.8826, Accuracy: 92.11%

# %%
# 데이터 변환에 데이터 증강 기법 추가
transform_augmented = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True)
])

# 데이터셋 및 로더 재정의
train_dataset_augmented = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform_augmented)
train_subset_augmented = torch.utils.data.Subset(train_dataset_augmented, subset_indices)
train_loader_augmented = torch.utils.data.DataLoader(train_subset_augmented, batch_size=64, shuffle=True)
